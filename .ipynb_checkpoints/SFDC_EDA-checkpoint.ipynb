# %% [markdown]
# # This notebook performs Exploratory Data Analysis on the Salesforce Case log export data

# %%
import os
import random

import numpy as np
import pandas as pd

# %% [markdown]
# # We read from the salesforce export data and check the first few rows

# %%
sfdc_data = pd.read_csv('C:/Users/GCNDP/SFDC.csv')
sfdc_data.head()
# Out:
#          Date                     Subject* Call Type        Assigned  \
# 0  11/15/2017  Call 11/15/2017, 3:04:13 PM   Inbound  Debra Greenlee
# 1    6/7/2018    Call 6/7/2018, 8:27:51 AM   Inbound  Debra Greenlee
# 2   5/10/2018   Call 5/10/2018, 3:11:45 PM   Inbound  Debra Greenlee
# 3    3/7/2018    Call 3/7/2018, 2:34:32 PM   Inbound  Debra Greenlee
# 4   6/18/2018  Call 6/18/2018, 10:09:15 AM   Inbound  Debra Greenlee
#
#   Call Object Identifier                               Call Recording  \
# 0     104792934020171115  http://10.64.30.192:8091/?callid=1047929340
# 1     304737374990180607  http://10.64.30.192:8091/?callid=3047373749
# 2     304730318670180510  http://10.64.30.192:8091/?callid=3047303186
# 3     204726086060180307  http://10.64.30.192:8091/?callid=2047260860
# 4     304740583190180618  http://10.64.30.192:8091/?callid=3047405831
#
#    Case Number     Case Owner*                 Case Subject Case Status  \
# 0     972606.0  Debra Greenlee                  JDF credits      Closed
# 1    1296323.0  Debra Greenlee  Farmflex Financing reversal      Closed
# 2    1267970.0  Debra Greenlee     New C3 user registration      Closed
# 3    1144423.0  Debra Greenlee             MyMonsanto Issue      Closed
# 4    1305717.0  Debra Greenlee                     Farmflex      Closed
#
#   Case Origin*                   Reason*  \
# 0        Phone                    Credit
# 1        Phone                    Credit
# 2        Phone           Systems Support
# 3        Phone  Manage Customer Accounts
# 4        Phone                    Credit
#
#                                     Case Description  Count of Comments  \
# 0  Valerie called about duplicate JDF credits on ...                1.0
# 1  Lisa called entered in a farmflex invoice in e...                1.0
# 2  Lisa Waddle needed assistance with registering...                1.0
# 3  Rahul, Darrell Scott with SAP: 1032247 AGRI AF...                2.0
# 4  Jennie looking for farmflex credit on three gr...                1.0
#
#                                    Last Case Comment Account Brand and Type  \
# 0  Valerie called about duplicate JDF credits on ...      National - Dealer
# 1  Lisa called entered in a farmflex invoice in e...      National - Dealer
# 2  Lisa Waddle needed assistance with registering...      National - Dealer
# 3  Darrell called trying access C3 User access to...      National - Dealer
# 4  Jennie looking for farmflex credit on three gr...      National - Dealer
#
#       SAP ID                 Account Name       Contact Name
# 0  1033841.0           MIDWAY CO-OP LURAY  Valerie Werthmann
# 1  3383451.0      GREENPOINT AG ALTHEIMER        Lisa Waddle
# 2  3383451.0      GREENPOINT AG ALTHEIMER        Lisa Waddle
# 3  1032247.0             AGRI AFC DECATUR      Darrell Scott
# 4  3623699.0  TALLAHATCHIE F S CHARLESTON      Jennie Mullen

# %% [markdown]
# # We check the Reason codes and their counts in the data, since our main goal is to classify a Case into its correct Reason code

# %%
sfdc_data['Reason*'].value_counts()
# Out:
# Delivery/Shipments          70
# Systems Support             50
# Returns                     30
# Credit                      21
# Refusals                    14
# Manage Customer Accounts    11
# Programs/Compensation       11
# Invoice                      8
# Compliance                   7
# Accounts Receivable          7
# Order Management             6
# Quality Of Service           6
# Inventory                    4
# Other                        3
# Product                      2
# Claims                       2
# Transfers/Swaps              2
# Pricing                      1
# Collection                   1
# Manage Sales partner         1
# Name: Reason*, dtype: int64

# %%
sfdc_data['Account Brand and Type'].value_counts()
# Out:
# National - Dealer     120
# Hubner - Dealer        75
# Specialty - Dealer     23
# Hubner - Grower        12
# Channel - Dealer        7
# Specialty - Grower      5
# - Dealer                5
# Jung - Dealer           2
# Stone - Dealer          2
# National - Grower       1
# Lewis - Grower          1
# Stewart - Dealer        1
# REA - Dealer            1
# WestBred - Grower       1
# Kruger - Grower         1
# Name: Account Brand and Type, dtype: int64

# %%
sfdc_data['Case Status'].value_counts()
# Out:
# Closed         254
# In Progress      3
# Name: Case Status, dtype: int64

# %%
sfdc_data['Call Type'].value_counts()
# Out:
# Outbound    151
# Inbound     106
# Name: Call Type, dtype: int64

# %% [markdown]
# # We filter out the five dominant reason codes for our analysis

# %%
#We take the four dominant reason codes
sfdc_data. rename(columns={'Reason*': 'Reason'}, inplace=True)
Reasons=['Delivery/Shipments','Systems Support','Returns','Credit','Refusals']
sfdc_data_filtered=sfdc_data[sfdc_data.Reason.isin(Reasons)]

# %%
sfdc_data_filtered['Reason'].value_counts()
# Out:
# Delivery/Shipments    70
# Systems Support       50
# Returns               30
# Credit                21
# Refusals              14
# Name: Reason, dtype: int64

# %% [markdown]
# # We assign a numeric code to each of these Reason codes, as given here

# %%
sfdc_data_filtered.loc[(sfdc_data_filtered['Reason']=='Delivery/Shipments'),'label']='0'
sfdc_data_filtered.loc[(sfdc_data_filtered['Reason']=='Systems Support'),'label']='1'
sfdc_data_filtered.loc[(sfdc_data_filtered['Reason']=='Returns'),'label']='2'
sfdc_data_filtered.loc[(sfdc_data_filtered['Reason']=='Credit'),'label']='3'
sfdc_data_filtered.loc[(sfdc_data_filtered['Reason']=='Refusals'),'label']='4'
# Out:
# C:\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
sfdc_data_filtered['label'].value_counts()
# Out:
# 0    70
# 1    50
# 2    30
# 3    21
# 4    14
# Name: label, dtype: int64

# %%
desc_text=sfdc_data_filtered['Case Description'].astype(str)
print(desc_text[0])
# Out:
# Valerie called about duplicate JDF credits on Winfield statement. 61963773 - 24,147.08 61963802 - 12, 916.20

# %%
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer


def plot_frequency_distribution_of_ngrams(sample_texts,
                                          ngram_range=(1, 2),
                                          num_ngrams=50):
    """Plots the frequency distribution of n-grams.

    # Arguments
        samples_texts: list, sample texts.
        ngram_range: tuple (min, mplt), The range of n-gram values to consider.
            Min and mplt are the lower and upper bound values for the range.
        num_ngrams: int, number of n-grams to plot.
            Top `num_ngrams` frequent n-grams will be plotted.
    """
    # Create args required for vectorizing.
    kwargs = {
            'ngram_range': (1, 2),
            'dtype': 'int32',
            'strip_accents': 'unicode',
            'decode_error': 'replace',
            'analyzer': 'word',  # Split text into word tokens.
    }
    vectorizer = CountVectorizer(**kwargs)

    # This creates a vocabulary (dict, where keys are n-grams and values are
    # idxices). This also converts every text to an array the length of
    # vocabulary, where every element idxicates the count of the n-gram
    # corresponding at that idxex in vocabulary.
    vectorized_texts = vectorizer.fit_transform(sample_texts)

    # This is the list of all n-grams in the index order from the vocabulary.
    all_ngrams = list(vectorizer.get_feature_names())
    num_ngrams = min(num_ngrams, len(all_ngrams))
    # ngrams = all_ngrams[:num_ngrams]

    # Add up the counts per n-gram ie. column-wise
    all_counts = vectorized_texts.sum(axis=0).tolist()[0]

    # Sort n-grams and counts by frequency and get top `num_ngrams` ngrams.
    all_counts, all_ngrams = zip(*[(c, n) for c, n in sorted(
        zip(all_counts, all_ngrams), reverse=True)])
    ngrams = list(all_ngrams)[:num_ngrams]
    counts = list(all_counts)[:num_ngrams]

    idx = np.arange(num_ngrams)
    

    plt.figure(figsize=(20, 3))  # width:20, height:3
    plt.bar(idx, counts, width=0.8, color='b')
    plt.xlabel('N-grams')
    plt.ylabel('Frequencies')
    #plt.axis([0,20,0,160])
    plt.title('Frequency distribution of n-grams')
    plt.xticks(idx, ngrams, rotation=45)
    plt.show()


def plot_sample_length_distribution(sample_texts):
    """Plots the sample length distribution.

    # Arguments
        samples_texts: list, sample texts.
    """
    plt.hist([len(s) for s in sample_texts], 50)
    plt.xlabel('Length of a sample')
    plt.ylabel('Number of samples')
    plt.title('Sample length distribution')
    plt.show()


def plot_class_distribution(labels):
    """Plots the class distribution.

    # Arguments
        labels: list, label values.
            There should be at lease one sample for values in the
            range (0, num_classes -1)
    """
    num_classes = get_num_classes(labels)
    count_map = Counter(labels)
    counts = [count_map[i] for i in range(num_classes)]
    idx = np.arange(num_classes)
    plt.bar(idx, counts, width=0.8, color='b')
    plt.xlabel('Class')
    plt.ylabel('Number of samples')
    plt.title('Class distribution')
    plt.xticks(idx, idx)
    plt.show()

# %%
corpus = sfdc_data_filtered['Case Description'].astype(str)

# %%
import re
import nltk
import string
exclude = set(string.punctuation) 
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')
newStopWords = ['lb','j','df','jdf']
stop_words.extend(newStopWords)
table = str.maketrans('', '', string.punctuation)
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
   # doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc, re.I)
   # doc = doc.lower()
   # doc = doc.strip()
    # tokenize document
    tokens = doc.split()
    # remove punctuation from each word
    tokens = [w.translate(table) for w in tokens]
    #wpt.tokenize(doc)
    # convert to lower case
    lower_tokens = [w.lower() for w in tokens]
    #remove spaces
    stripped = [w.strip() for w in lower_tokens]
    # remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
    # filter stopwords out of document
    filtered_tokens = [token for token in words if token not in stop_words]
    #apply Stemming
    #stemmed = [porter.stem(word) for word in filtered_tokens]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %% [markdown]
# # We tokenize the Case Description and normalize the text by removing punctuation, spaces, stop words, leading and trailing blanks

# %%
norm_corpus = normalize_corpus(corpus)

# %% [markdown]
# # We check the median number of words per sample row

# %%
#Median number of words per sample
num_words = [len(sfdc_data_filtered['Case Description'].astype(str).str.split()) for s in desc_text]
print(np.median(num_words))
# Out:
# 185.0

# %% [markdown]
# # Plot of frequency distribution of n-grams in the Case Description text

# %%
plot_frequency_distribution_of_ngrams(norm_corpus)

# %% [markdown]
# # Plot of length distribution of Case Description

# %%
plot_sample_length_distribution(desc_text)

# %% [markdown]
# # Plot of class distribution of the Case Description text (each class representing a Reason)

# %%
num_classes = 5
count_map = Counter(sfdc_data_filtered['label'])
print(count_map)
counts = count_map.values()
print(counts)
[count_map[i] for i in range(num_classes)]
idx = np.arange(num_classes)
print(idx)
plt.bar(idx, counts, width=0.8, color='b')
plt.xlabel('Class')
plt.ylabel('Number of samples')
plt.title('Class distribution')
plt.xticks(idx, idx)
plt.show()
# Out:
# Counter({'0': 70, '1': 50, '2': 30, '3': 21, '4': 14})
# dict_values([21, 50, 70, 30, 14])
# [0 1 2 3 4]

# %% [markdown]
# # We plot freq distribution and Word Cloud for each of the 4 dominant reason codes

# %% [markdown]
# # 'Delivery/Shipments'

# %%
Desc_del=sfdc_data_filtered[sfdc_data_filtered['Reason']=='Delivery/Shipments']
Delivery_txt=(Desc_del['Case Description'].astype(str))
norm_corpus_del = normalize_corpus(Delivery_txt)
#print(norm_corpus_del[:300])
plot_frequency_distribution_of_ngrams(norm_corpus_del)

# %% [markdown]
# # 'Systems Support'

# %%
Desc_supp=sfdc_data_filtered[sfdc_data_filtered['Reason']=='Systems Support']
Support_txt=Desc_supp['Case Description'].astype(str)
norm_corpus_supp = normalize_corpus(Support_txt)
plot_frequency_distribution_of_ngrams(norm_corpus_supp)

# %% [markdown]
# # 'Returns'

# %%
Desc_ret=sfdc_data_filtered[sfdc_data_filtered['Reason']=='Returns']
Return_txt=Desc_ret['Case Description'].astype(str)
norm_corpus_ret = normalize_corpus(Return_txt)
plot_frequency_distribution_of_ngrams(norm_corpus_ret)

# %% [markdown]
# # 'Credit'

# %%
Desc_credit=sfdc_data_filtered[sfdc_data_filtered['Reason']=='Credit']
Credit_txt=Desc_credit['Case Description'].astype(str)
norm_corpus_credit = normalize_corpus(Credit_txt)
plot_frequency_distribution_of_ngrams(norm_corpus_credit)

# %%
from wordcloud import WordCloud, STOPWORDS

from nltk.tokenize import word_tokenize
import string
from nltk.corpus import stopwords
stop_words = nltk.corpus.stopwords.words('english')
newStopWords = ['lb','j','df','jdf']
stop_words.extend(newStopWords)
wpt = nltk.WordPunctTokenizer()

def normalize_text(text):
    tokens = word_tokenize(text)
    # convert to lower case
    tokens = [w.lower() for w in tokens]
    # remove punctuation from each word
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
    # filter out stop words
    words = [w for w in words if not w in stop_words]
    print(words[:100])
    doc = ' '.join(words)
    return doc

def generate_wordcloud(text):
    wordcloud = WordCloud().generate(normalize_text(text))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
    return wordcloud

# %% [markdown]
# # 'Delivery/Shipment' Word Cloud

# %%
wordcloud = generate_wordcloud(' '.join(Delivery_txt))
wordcloud.words_
# Out:
# ['rick', 'called', 'needs', 'signed', 'bol', 'mon', 'inv', 'greenpoint', 'ag', 'clarksdale', 'shipped', 'matthews', 'mo', 'shipment', 'date', 'jan', 'asked', 'kelly', 'office', 'transferred', 'jaime', 'action', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'deleted', 'due', 'ship', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'replaced', 'po', 'required', 'transaction', 'replaced', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'po', 'required', 'transaction', 'matt', 'would', 'like', 'delivery', 'going', 'vacation', 'matt', 'phone', 'number', 'prefers', 'cjf', 'biddick', 'morning', 'delivery', 'medium', 'seed', 'entire', 'order', 'cosif', 'exceptions', 'small', 'seed', 'please', 'point', 'shipment', 'please', 'update', 'bucket', 'date', 'ylaspick', 'send', 'laura', 'weigle', 'complete']
# {'po required': 1.0,
#  'required transaction': 1.0,
#  'transaction po': 0.8666666666666667,
#  'update bucket': 0.5166666666666667,
#  'bucket date': 0.5166666666666667,
#  'date ylaspick': 0.5166666666666667,
#  'please update': 0.48333333333333334,
#  'ylaspick send': 0.4666666666666667,
#  'send laura': 0.4666666666666667,
#  'laura weigle': 0.4666666666666667,
#  'weigle complete': 0.4666666666666667,
#  'complete laura': 0.2,
#  'complete please': 0.2,
#  'delivery': 0.11666666666666667,
#  'matt': 0.1,
#  'seed size': 0.1,
#  'size preference': 0.08333333333333333,
#  'let know': 0.08333333333333333,
#  'order': 0.06666666666666667,
#  'avoid': 0.06666666666666667,
#  'customer': 0.06666666666666667,
#  'add': 0.06666666666666667,
#  'pallet': 0.06666666666666667,
#  'tony': 0.06666666666666667,
#  'fulfilled': 0.06666666666666667,
#  'load': 0.06666666666666667,
#  'preference attached': 0.06666666666666667,
#  'ship': 0.05,
#  'going': 0.05,
#  'please': 0.05,
#  'schedule': 0.05,
#  'bags': 0.05,
#  'scheduled': 0.05,
#  'everything': 0.05,
#  'prefer': 0.05,
#  'truck': 0.05,
#  'contact': 0.05,
#  'use': 0.05,
#  'pick': 0.05,
#  'back': 0.05,
#  'benjamin': 0.05,
#  'trucking possible': 0.05,
#  'called': 0.03333333333333333,
#  'shipment': 0.03333333333333333,
#  'deleted': 0.03333333333333333,
#  'due': 0.03333333333333333,
#  'replaced': 0.03333333333333333,
#  'morning': 0.03333333333333333,
#  'seed': 0.03333333333333333,
#  'daryl': 0.03333333333333333,
#  'dealership': 0.03333333333333333,
#  'zeiset': 0.03333333333333333,
#  'reiff': 0.03333333333333333,
#  'availability': 0.03333333333333333,
#  'overweight': 0.03333333333333333,
#  'take': 0.03333333333333333,
#  'palletize': 0.03333333333333333,
#  'hybrid': 0.03333333333333333,
#  'pull': 0.03333333333333333,
#  'forward': 0.03333333333333333,
#  'week': 0.03333333333333333,
#  'ok': 0.03333333333333333,
#  'per': 0.03333333333333333,
#  'alton': 0.03333333333333333,
#  'dale': 0.03333333333333333,
#  'agric': 0.03333333333333333,
#  'commodities': 0.03333333333333333,
#  'following': 0.03333333333333333,
#  'deliveries': 0.03333333333333333,
#  'something': 0.03333333333333333,
#  'hunter': 0.03333333333333333,
#  'try': 0.03333333333333333,
#  'need': 0.03333333333333333,
#  'rick': 0.016666666666666666,
#  'signed': 0.016666666666666666,
#  'bol': 0.016666666666666666,
#  'mon': 0.016666666666666666,
#  'inv': 0.016666666666666666,
#  'greenpoint': 0.016666666666666666,
#  'ag': 0.016666666666666666,
#  'clarksdale': 0.016666666666666666,
#  'shipped': 0.016666666666666666,
#  'matthews': 0.016666666666666666,
#  'mo': 0.016666666666666666,
#  'jan': 0.016666666666666666,
#  'asked': 0.016666666666666666,
#  'kelly': 0.016666666666666666,
#  'office': 0.016666666666666666,
#  'transferred': 0.016666666666666666,
#  'jaime': 0.016666666666666666,
#  'action': 0.016666666666666666,
#  'vacation': 0.016666666666666666,
#  'phone': 0.016666666666666666,
#  'number': 0.016666666666666666,
#  'cjf': 0.016666666666666666,
#  'biddick': 0.016666666666666666,
#  'medium': 0.016666666666666666,
#  'entire': 0.016666666666666666,
#  'cosif': 0.016666666666666666,
#  'exceptions': 0.016666666666666666,
#  'small': 0.016666666666666666,
#  'point': 0.016666666666666666,
#  'must': 0.016666666666666666,
#  'first': 0.016666666666666666,
#  'thing': 0.016666666666666666,
#  'afternoon': 0.016666666666666666,
#  'come': 0.016666666666666666,
#  'tomorrow': 0.016666666666666666,
#  'spreadsheet': 0.016666666666666666,
#  'attached': 0.016666666666666666,
#  'follow': 0.016666666666666666,
#  'accommodated': 0.016666666666666666,
#  'minimum': 0.016666666666666666,
#  'amount': 0.016666666666666666,
#  'full': 0.016666666666666666,
#  'weight': 0.016666666666666666,
#  'necessary': 0.016666666666666666,
#  'notes': 0.016666666666666666,
#  'anyone': 0.016666666666666666,
#  'units': 0.016666666666666666,
#  'ricki': 0.016666666666666666,
#  'ca': 0.016666666666666666,
#  'nt': 0.016666666666666666,
#  'january': 0.016666666666666666,
#  'elvin': 0.016666666666666666,
#  'said': 0.016666666666666666,
#  'next': 0.016666666666666666,
#  'asap': 0.016666666666666666,
#  'replace': 0.016666666666666666,
#  'damaged': 0.016666666666666666,
#  'priority': 0.016666666666666666,
#  'requested': 0.016666666666666666,
#  'troy': 0.016666666666666666,
#  'jason': 0.016666666666666666,
#  'hour': 0.016666666666666666,
#  'prior': 0.016666666666666666,
#  'goatley': 0.016666666666666666,
#  'picked': 0.016666666666666666,
#  'corn': 0.016666666666666666,
#  'indianola': 0.016666666666666666,
#  'plant': 0.016666666666666666,
#  'billy': 0.016666666666666666,
#  'palmer': 0.016666666666666666,
#  'appointment': 0.016666666666666666,
#  'keller': 0.016666666666666666,
#  'shipping': 0.016666666666666666,
#  'person': 0.016666666666666666,
#  'scheduling': 0.016666666666666666,
#  'nan': 0.016666666666666666,
#  'talked': 0.016666666666666666,
#  'wanting': 0.016666666666666666,
#  'put': 0.016666666666666666,
#  'hall': 0.016666666666666666,
#  'want': 0.016666666666666666,
#  'start': 0.016666666666666666,
#  'planting': 0.016666666666666666,
#  'told': 0.016666666666666666,
#  'check': 0.016666666666666666,
#  'call': 0.016666666666666666,
#  'ordered': 0.016666666666666666,
#  'rod': 0.016666666666666666}

# %% [markdown]
# # 'Systems Support' Word Cloud

# %%
#Support_txt1 = ''.join(norm_corpus_supp)
generate_wordcloud(' '.join(Support_txt))
# Out:
# ['lisa', 'waddle', 'needed', 'assistance', 'registering', 'winfield', 'businesslink', 'new', 'user', 'roman', 'needed', 'help', 'new', 'path', 'gpos', 'access', 'stock', 'transfers', 'mymonsanto', 'dale', 'duckworth', 'needs', 'access', 'winfield', 'businesslink', 'gpos', 'access', 'mymon', 'heidi', 'send', 'file', 'overnight', 'grant', 'access', 'per', 'tracy', 'returns', 'tools', 'mymonsanto', 'working', 'winfield', 'customer', 'service', 'chelsea', 'bennett', 'user', 'id', 'greenpoint', 'ag', 'blytheville', 'needs', 'access', 'gpos', 'tab', 'winfield', 'businesslink', 'marv', 'happy', 'connect', 'maintenance', 'able', 'assist', 'getting', 'busineslink', 'gpos', 'tab', 'missing', 'tabs', 'mymon', 'showing', 'janet', 'called', 'trying', 'enter', 'grower', 'orders', 'growers', 'list', 'prdt', 'list', 'janet', 'called', 'trying', 'enter', 'grower', 'orders', 'growers', 'list', 'prdt', 'list', 'brian', 'missing', 'grower', 'order', 'tab', 'mm', 'devan', 'getting', 'login', 'screen']

# %% [markdown]
# # 'Returns' Word Cloud

# %%
#Return_txt1 = ''.join(norm_corpus_ret)
generate_wordcloud(' '.join(Return_txt))
# Out:
# ['jo', 'ellen', 'looking', 'return', 'bags', 'pu', 'andy', 'please', 'call', 'hours', 'advance', 'well', 'hour', 'arrival', 'alma', 'take', 'south', 'cross', 'state', 'line', 'west', 'almena', 'block', 'west', 'school', 'anytime', 'week', 'fine', 'paul', 'called', 'let', 'know', 'going', 'able', 'return', 'recalled', 'boxes', 'already', 'delivered', 'customer', 'told', 'mark', 'driver', 'paperwork', 'actually', 'returning', 'mentioned', 'also', 'typed', 'asked', 'email', 'information', 'well', 'could', 'copy', 'discrepancies', 'product', 'back', 'warehouse', 'john', 'let', 'know', 'brad', 'ready', 'returns', 'bags', 'corn', 'bags', 'soybeans', 'empty', 'boxes', 'mike', 'called', 'let', 'know', 'returns', 'ready', 'scheduled', 'pickup', 'bags', 'corn', 'bags', 'soybeans', 'boxes', 'soybeans', 'empty', 'boxes', 'pick', 'okay', 'per', 'heath', 'please', 'call', 'hour', 'prior', 'delivery', 'talked', 'taylor', 'go', 'mymonsanto']

# %% [markdown]
# # 'Credit' Word Cloud

# %%
#Credit_txt1 = ''.join(norm_corpus_credit)
generate_wordcloud(' '.join(Credit_txt))
# Out:
# ['valerie', 'called', 'duplicate', 'credits', 'winfield', 'statement', 'lisa', 'called', 'entered', 'farmflex', 'invoice', 'error', 'needed', 'help', 'reverse', 'mymonsanto', 'jennie', 'looking', 'farmflex', 'credit', 'three', 'growers', 'vicki', 'needed', 'help', 'access', 'new', 'path', 'winfield', 'businesslink', 'pam', 'called', 'wanted', 'know', 'grower', 'paid', 'full', 'farm', 'flex', 'winfield', 'invoice', 'brent', 'wanted', 'know', 'ecd', 'payment', 'grower', 'troy', 'smyres', 'windom', 'ks', 'used', 'kenny', 'nowell', 'winfield', 'dsm', 'wanted', 'know', 'two', 'winfield', 'invoices', 'invoices', 'farmflex', 'grower', 'financing', 'charges', 'conrad', 'newberry', 'bufford', 'newberry', 'beja', 'looking', 'grower', 'financing', 'jones', 'wyatt', 'farms', 'ff', 'team', 'asking', 'financial', 'statement', 'sent', 'beja', 'looking', 'grower', 'financing', 'jones', 'wyatt', 'farms', 'ff', 'team', 'asking', 'financial', 'statement', 'sent', 'beja', 'looking', 'financing', 'grower']
